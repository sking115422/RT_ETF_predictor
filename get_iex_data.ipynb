# %%
import requests
import private_info as pi 
import pandas as pd

# %%
iex_token = pi.iex_token

# %%
api_url = f'https://cloud.iexapis.com/stable/stock/aapl/quote?token={iex_token}'

# %%
data = requests.get(api_url).json()

# %%
df = pd.DataFrame.from_dict(data, orient="index")

# %%
df
# Out:
#                                               0
# avgTotalVolume                        123821575
# calculationPrice                          close
# change                                     3.24
# changePercent                           0.01909
# close                                    172.99
# closeSource                            official
# closeTime                         1640120400749
# companyName                           Apple Inc
# currency                                    USD
# delayedPrice                             173.03
# delayedPriceTime                  1640120399962
# extendedChange                            -0.42
# extendedChangePercent                  -0.00243
# extendedPrice                            172.57
# extendedPriceTime                 1640134793790
# high                                      173.2
# highSource              15 minute delayed price
# highTime                          1640120399974
# iexAskPrice                                   0
# ...
